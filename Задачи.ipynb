# %%
name = input()
print('Hello,', name)
# Out:
# Harry!
# Hello, Harry!

# %%
print("Введите число от 1 до 9 сколько пингвинов вывести: ")
a = int(input())
if a >= 1 and a <= 9:
    [Код решения удален командой курса]
elif a < 1:
    print("Введите число меньше 1")
elif a > 9:
    print("Введите число больше 9")
# Out:
#   File "<ipython-input-3-3363598fa810>", line 4
#     [Код решения удален командой курса]
#                ^
# SyntaxError: invalid syntax
